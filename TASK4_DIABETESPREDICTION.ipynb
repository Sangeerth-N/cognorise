# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/diabetes_prediction_dataset.csv')
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %%
# Visualising the distribution between Gender and Diabetes
import matplotlib.pyplot as plt
import seaborn as sns
ax = sns.countplot(x='gender', hue='diabetes', data=df, palette= "Set1")
for label in ax.containers:
    ax.bar_label(label)
plt.show()

# %%
# Visualising the distribution between Hyptertension and Diabetes
bx = sns.countplot(x='hypertension', hue='diabetes', data=df, palette='Dark2')
for label in bx.containers:
    bx.bar_label(label)
plt.show()

# %%
# Visualising the distribution between Heart_disease and Diabetes
cx = sns.countplot(x='heart_disease', hue='diabetes', data=df, palette='RdPu_r')
for label in cx.containers:
    cx.bar_label(label)
plt.show()

# %%
# Visualising the relationship between BMI and Diabetes
sns.lineplot(y='bmi', x='diabetes', data=df)
# Out:
# <Axes: xlabel='diabetes', ylabel='bmi'>

# %%
# Visualising the relationship between Age and Diabetes
sns.lineplot(x='age', y='diabetes', data=df)
# Out:
# <Axes: xlabel='age', ylabel='diabetes'>

# %%
# Using .get_dummies function to convert the categorical datatype to numerical and storing the returned dataFrame in a new variable df1
df1 = pd.get_dummies(df['gender'])
df1
# Out:
#        Female   Male  Other
# 0        True  False  False
# 1        True  False  False
# 2       False   True  False
# 3        True  False  False
# 4       False   True  False
# ...       ...    ...    ...
# 99995    True  False  False
# 99996    True  False  False
# 99997   False   True  False
# 99998    True  False  False
# 99999    True  False  False
#
# [100000 rows x 3 columns]

# %%
# Using pd.concat to concatenate the dataframes df and df1 and storing the concatenated dataFrame in df.
df = pd.concat([df, df1], axis=1)
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes  Female   Male  Other
# 0              6.6                  140         0    True  False  False
# 1              6.6                   80         0    True  False  False
# 2              5.7                  158         0   False   True  False
# 3              5.0                  155         0    True  False  False
# 4              4.8                  155         0   False   True  False
# ...            ...                  ...       ...     ...    ...    ...
# 99995          6.2                   90         0    True  False  False
# 99996          6.5                  100         0    True  False  False
# 99997          5.7                  155         0   False   True  False
# 99998          4.0                  100         0    True  False  False
# 99999          6.6                   90         0    True  False  False
#
# [100000 rows x 12 columns]

# %%
# Removing the column 'gender' from df as it is of no use now.
df.drop('gender', axis=1, inplace=True)
df
# Out:
#         age  hypertension  heart_disease smoking_history    bmi  HbA1c_level  \
# 0      80.0             0              1           never  25.19          6.6
# 1      54.0             0              0         No Info  27.32          6.6
# 2      28.0             0              0           never  27.32          5.7
# 3      36.0             0              0         current  23.45          5.0
# 4      76.0             1              1         current  20.14          4.8
# ...     ...           ...            ...             ...    ...          ...
# 99995  80.0             0              0         No Info  27.32          6.2
# 99996   2.0             0              0         No Info  17.37          6.5
# 99997  66.0             0              0          former  27.83          5.7
# 99998  24.0             0              0           never  35.42          4.0
# 99999  57.0             0              0         current  22.43          6.6
#
#        blood_glucose_level  diabetes  Female   Male  Other
# 0                      140         0    True  False  False
# 1                       80         0    True  False  False
# 2                      158         0   False   True  False
# 3                      155         0    True  False  False
# 4                      155         0   False   True  False
# ...                    ...       ...     ...    ...    ...
# 99995                   90         0    True  False  False
# 99996                  100         0    True  False  False
# 99997                  155         0   False   True  False
# 99998                  100         0    True  False  False
# 99999                   90         0    True  False  False
#
# [100000 rows x 11 columns]

# %%
# We use .map() on a specific column and provide a dictionary to perform the mapping
df['Female'] = df['Female'].map({True: 1, False: 0})
df['Male'] = df['Male'].map({True: 1, False: 0})
df['Other'] = df['Other'].map({True: 1, False: 0})

# %%
df.head(5)
# Out:
#     age  hypertension  heart_disease smoking_history    bmi  HbA1c_level  \
# 0  80.0             0              1           never  25.19          6.6
# 1  54.0             0              0         No Info  27.32          6.6
# 2  28.0             0              0           never  27.32          5.7
# 3  36.0             0              0         current  23.45          5.0
# 4  76.0             1              1         current  20.14          4.8
#
#    blood_glucose_level  diabetes  Female  Male  Other
# 0                  140         0       1     0      0
# 1                   80         0       1     0      0
# 2                  158         0       0     1      0
# 3                  155         0       1     0      0
# 4                  155         0       0     1      0

# %%
# Drop the 'smoking_history' column as it is non-numeric and we do not handle it here
df.drop('smoking_history', axis=1, inplace=True)
df
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99995  80.0             0              0  27.32          6.2
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  Female  Male  Other
# 0                      140         0       1     0      0
# 1                       80         0       1     0      0
# 2                      158         0       0     1      0
# 3                      155         0       1     0      0
# 4                      155         0       0     1      0
# ...                    ...       ...     ...   ...    ...
# 99995                   90         0       1     0      0
# 99996                  100         0       1     0      0
# 99997                  155         0       0     1      0
# 99998                  100         0       1     0      0
# 99999                   90         0       1     0      0
#
# [100000 rows x 10 columns]

# %%
x = df.drop(columns=['diabetes'])
y = df['diabetes']
x
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99995  80.0             0              0  27.32          6.2
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  Female  Male  Other
# 0                      140       1     0      0
# 1                       80       1     0      0
# 2                      158       0     1      0
# 3                      155       1     0      0
# 4                      155       0     1      0
# ...                    ...     ...   ...    ...
# 99995                   90       1     0      0
# 99996                  100       1     0      0
# 99997                  155       0     1      0
# 99998                  100       1     0      0
# 99999                   90       1     0      0
#
# [100000 rows x 9 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %%
pd.value_counts(y)
# Out:
# <ipython-input-21-0e04e23f3b37>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(y)
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 76513  49.0             0              0  27.32          5.0
# 60406  64.0             0              0  27.32          3.5
# 27322  24.0             0              0  27.32          3.5
# 53699  55.0             0              0  27.32          6.5
# 65412  14.0             0              0  20.98          6.2
# ...     ...           ...            ...    ...          ...
# 6265   49.0             0              0  32.98          5.7
# 54886  15.0             0              0  28.10          5.0
# 76820  42.0             0              0  26.14          5.8
# 860    37.0             0              0  24.96          6.2
# 15795  23.0             0              0  27.99          5.0
#
#        blood_glucose_level  Female  Male  Other
# 76513                  155       0     1      0
# 60406                  145       0     1      0
# 27322                  130       1     0      0
# 53699                  159       1     0      0
# 65412                   85       0     1      0
# ...                    ...     ...   ...    ...
# 6265                    80       0     1      0
# 54886                  159       1     0      0
# 76820                   85       0     1      0
# 860                    158       1     0      0
# 15795                  159       1     0      0
#
# [70000 rows x 9 columns]

# %%
x_test
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 75721  13.0             0              0  20.82          5.8
# 80184   3.0             0              0  21.00          5.0
# 19864  63.0             0              0  25.32          3.5
# 76699   2.0             0              0  17.43          6.1
# 92991  33.0             0              0  40.08          6.2
# ...     ...           ...            ...    ...          ...
# 42648  51.0             0              0  24.68          7.0
# 86306  28.0             0              0  18.94          6.0
# 45466  80.0             0              1  33.03          6.6
# 63724  80.0             0              0  27.32          6.2
# 34122  26.0             0              0  20.67          3.5
#
#        blood_glucose_level  Female  Male  Other
# 75721                  126       1     0      0
# 80184                  145       1     0      0
# 19864                  200       0     1      0
# 76699                  126       1     0      0
# 92991                  200       1     0      0
# ...                    ...     ...   ...    ...
# 42648                  200       0     1      0
# 86306                   90       0     1      0
# 45466                  100       1     0      0
# 63724                  200       1     0      0
# 34122                  100       1     0      0
#
# [30000 rows x 9 columns]

# %%
y_train
# Out:
# 76513    0
# 60406    0
# 27322    0
# 53699    0
# 65412    0
#         ..
# 6265     0
# 54886    0
# 76820    0
# 860      0
# 15795    0
# Name: diabetes, Length: 70000, dtype: int64

# %%
y_test
# Out:
# 75721    0
# 80184    0
# 19864    0
# 76699    0
# 92991    1
#         ..
# 42648    1
# 86306    0
# 45466    0
# 63724    0
# 34122    0
# Name: diabetes, Length: 30000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay,classification_report
acc=accuracy_score(y_test,y_pred)
print("ACCURACY SCORE",acc)
cm=confusion_matrix(y_test,y_pred)
print("CONFUSION MATRIX",cm)
# Out:
# ACCURACY SCORE 0.9638
# CONFUSION MATRIX [[27327   126]
#  [  960  1587]]

# %%
cmd=ConfusionMatrixDisplay(confusion_matrix=cm)  # Pass the confusion matrix to ConfusionMatrixDisplay
cmd.plot()
print("CONFUSION MATRIX DISPLAY")
cr=classification_report(y_test,y_pred)
print("CLASSIFICATION REPORT",cr)
# Out:
# CONFUSION MATRIX DISPLAY
# CLASSIFICATION REPORT               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     27453
#            1       0.93      0.62      0.75      2547
#
#     accuracy                           0.96     30000
#    macro avg       0.95      0.81      0.86     30000
# weighted avg       0.96      0.96      0.96     30000
